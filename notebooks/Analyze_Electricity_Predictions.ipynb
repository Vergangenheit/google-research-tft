# %% [markdown]
# check if they are conducive to the paper's claims

# %%
import sys
sys.path.insert(0, '..')

# %%
from data_formatters.base import GenericDataFormatter, InputTypes, DataTypes
from data_formatters.electricity import ElectricityFormatter
from expt_settings.configs import ExperimentConfig
from libs.hyperparam_opt import HyperparamOptManager
from libs.tft_model import TemporalFusionTransformer
import libs.utils as utils
import os
import pandas as pd
from pandas import DataFrame, Series, Timestamp, Index
from tqdm import tqdm

# %%
import numpy as np
import tensorflow as tf
import random
import tensorflow.compat.v1 as tf1
from tensorflow.compat.v1 import Session, ConfigProto
from tensorflow.python.eager.context import PhysicalDevice
from typing import Dict, List, Union, Generator
from numpy import load, array_equal, allclose

# %%
if tf.test.gpu_device_name(): 
    print('Default GPU Device:{}'.format(tf.test.gpu_device_name()))
else:
    print("Please install GPU version of TF")
# Out:
# Default GPU Device:/device:GPU:0

# %%
gpu: List[PhysicalDevice] = tf.config.experimental.list_physical_devices('GPU')
tf.config.experimental.set_memory_growth(gpu[0], True)

# %%
# Tensorflow setup
default_keras_session: Session = tf1.keras.backend.get_session()
tf_config: ConfigProto = utils.get_default_tensorflow_config(tf_device="gpu", gpu_id=0)
# Out:
# Selecting GPU ID=0

# %%
file_path: str = r'C:\Users\Lorenzo\PycharmProjects\TFT\outputs\data\electricity\data\hourly_electricity.csv'

# %%
raw_data: DataFrame = pd.read_csv(file_path)
raw_data['date'] = raw_data['date'].astype('datetime64[s]')

# %%
config = ExperimentConfig('electricity', r'C:\Users\Lorenzo\PycharmProjects\TFT\outputs')

# %%
formatter: ElectricityFormatter = config.make_data_formatter()

# %%
data_csv_path: str = config.data_csv_path

# %% [markdown]
# # SPLIT DATA

# %%
train, valid, test = formatter.split_data(raw_data)
# Out:
# Formatting train-valid-test splits.
# Setting scalers with training data...

# %%
column_definitions = formatter.get_column_definition()

# %%
train_samples, valid_samples = formatter.get_num_samples_for_calibration()

# %%
# Sets up default params
fixed_params: Dict = formatter.get_experiment_params()
params: Dict = formatter.get_default_model_params()
params["model_folder"]: str = os.path.join(config.model_folder, "fixed")
model_folder = os.path.join(config.model_folder, "fixed")

# %%
# Sets up hyperparam manager
print("*** Loading hyperparm manager ***")
opt_manager = HyperparamOptManager({k: [params[k]] for k in params},
                                   fixed_params, model_folder)
# Out:
# *** Loading hyperparm manager ***

# %%
model_folder: str = opt_manager.hyperparam_folder

# %% [markdown]
# # PREDICTION

# %%
print("*** Running tests ***")
tf1.reset_default_graph()
with tf.Graph().as_default(), tf1.Session(config=tf_config) as sess:
    tf1.keras.backend.set_session(sess)
    params: Dict = opt_manager.get_next_parameters()
    params['exp_name'] = 'electricity'
    params['data_folder'] = os.path.abspath(os.path.join(data_csv_path, os.pardir))
    model = TemporalFusionTransformer(params, use_cudnn=False)
    params.pop('exp_name', None)
    params.pop('data_folder', None)
    # load model
    model.load(opt_manager.hyperparam_folder, use_keras_loadings=True)
    
#     print("Computing best validation loss")
#     val_loss: Series = model.evaluate(valid)
        
    print("Computing test loss")
    output_map: Dict = model.predict(test, return_targets=True)
    print(f"Output map returned a dict with keys {output_map.get('p50').shape}")
    targets: DataFrame = formatter.format_predictions(output_map["targets"])
    p50_forecast: DataFrame = formatter.format_predictions(output_map["p50"])
    p90_forecast: DataFrame = formatter.format_predictions(output_map["p90"])
        
    # save all
    print("saving predictions and targets")
    targets.to_csv(os.path.join(opt_manager.hyperparam_folder, "targets.csv"), index=False)
    p50_forecast.to_csv(os.path.join(opt_manager.hyperparam_folder, "p50.csv"), index=False)
    p90_forecast.to_csv(os.path.join(opt_manager.hyperparam_folder, "p90.csv"), index=False)
        
    def extract_numerical_data(data: DataFrame) -> DataFrame:
        """Strips out forecast time and identifier columns."""
        return data[[
            col for col in data.columns
            if col not in {"forecast_time", "identifier"}
        ]]
    
    p50_loss = utils.numpy_normalised_quantile_loss(
            extract_numerical_data(targets), extract_numerical_data(p50_forecast),
            0.5)
    p90_loss = utils.numpy_normalised_quantile_loss(
        extract_numerical_data(targets), extract_numerical_data(p90_forecast),
        0.9)

    tf1.keras.backend.set_session(default_keras_session)

print()
print("Normalised Quantile Loss for Test Data: P50={}, P90={}".format(
    p50_loss.mean(), p90_loss.mean()))
# Out:
# *** Running tests ***
# Resetting temp folder...
# *** TemporalFusionTransformer params ***
# # dropout_rate = 0.1
# # hidden_layer_size = 160
# # learning_rate = 0.001
# # max_gradient_norm = 0.01
# # minibatch_size = 64
# # model_folder = C:\Users\Lorenzo\PycharmProjects\TFT\outputs\saved_models\electricity\fixed
# # num_heads = 4
# # stack_size = 1
# # total_time_steps = 192
# # num_encoder_steps = 168
# # num_epochs = 100
# # early_stopping_patience = 5
# # multiprocessing_workers = 5
# # column_definition = [('id', <DataTypes.REAL_VALUED: 0>, <InputTypes.ID: 4>), ('date', <DataTypes.DATE: 2>, <InputTypes.TIME: 5>), ('power_usage', <DataTypes.REAL_VALUED: 0>, <InputTypes.TARGET: 0>), ('hour', <DataTypes.REAL_VALUED: 0>, <InputTypes.KNOWN_INPUT: 2>), ('day_of_week', <DataTypes.REAL_VALUED: 0>, <InputTypes.KNOWN_INPUT: 2>), ('hours_from_start', <DataTypes.REAL_VALUED: 0>, <InputTypes.KNOWN_INPUT: 2>), ('categorical_id', <DataTypes.CATEGORICAL: 1>, <InputTypes.STATIC_INPUT: 3>)]
# # input_size = 5
# # output_size = 1
# # category_counts = [369]
# # input_obs_loc = [0]
# # static_input_loc = [4]
# # known_regular_inputs = [1, 2, 3]
# # known_categorical_inputs = [0]
# # exp_name = electricity
# # data_folder = C:\Users\Lorenzo\PycharmProjects\TFT\outputs\data\electricity\data
# WARNING:tensorflow:Layer lstm will not use cuDNN kernel since it doesn't meet the cuDNN kernel criteria. It will use generic GPU kernel as fallback when running on GPU
# WARNING:tensorflow:Layer lstm_1 will not use cuDNN kernel since it doesn't meet the cuDNN kernel criteria. It will use generic GPU kernel as fallback when running on GPU
# Model: "model"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            [(None, 192, 5)]     0
# __________________________________________________________________________________________________
# tf_op_layer_TemporalFusionTrans [(None, 192, 1)]     0           input_1[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_TemporalFusionTrans [(None, 192)]        0           tf_op_layer_TemporalFusionTransfo
# __________________________________________________________________________________________________
# sequential (Sequential)         (None, 192, 160)     59040       tf_op_layer_TemporalFusionTransfo
# __________________________________________________________________________________________________
# tf_op_layer_TemporalFusionTrans [(None, 160)]        0           sequential[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_TemporalFusionTrans [(None, 1, 160)]     0           tf_op_layer_TemporalFusionTransfo
# __________________________________________________________________________________________________
# flatten (Flatten)               (None, 160)          0           tf_op_layer_TemporalFusionTransfo
# __________________________________________________________________________________________________
# dense_5 (Dense)                 (None, 160)          25760       flatten[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_TemporalFusionTrans [(None, 1, 160)]     0           tf_op_layer_TemporalFusionTransfo
# __________________________________________________________________________________________________
# activation (Activation)         (None, 160)          0           dense_5[0][0]
# __________________________________________________________________________________________________
# dense_9 (Dense)                 (None, 1, 160)       25760       tf_op_layer_TemporalFusionTransfo
# __________________________________________________________________________________________________
# dense_6 (Dense)                 (None, 160)          25760       activation[0][0]
# __________________________________________________________________________________________________
# activation_2 (Activation)       (None, 1, 160)       0           dense_9[0][0]
# __________________________________________________________________________________________________
# dropout (Dropout)               (None, 160)          0           dense_6[0][0]
# __________________________________________________________________________________________________
# dense_10 (Dense)                (None, 1, 160)       25760       activation_2[0][0]
# __________________________________________________________________________________________________
# dense_7 (Dense)                 (None, 1)            161         dropout[0][0]
# __________________________________________________________________________________________________
# dense_8 (Dense)                 (None, 1)            161         dropout[0][0]
# __________________________________________________________________________________________________
# dropout_1 (Dropout)             (None, 1, 160)       0           dense_10[0][0]
# __________________________________________________________________________________________________
# dense_4 (Dense)                 (None, 1)            161         flatten[0][0]
# __________________________________________________________________________________________________
# multiply (Multiply)             (None, 1)            0           dense_7[0][0]
#                                                                  dense_8[0][0]
# __________________________________________________________________________________________________
# dense_11 (Dense)                (None, 1, 160)       25760       dropout_1[0][0]
# __________________________________________________________________________________________________
# dense_12 (Dense)                (None, 1, 160)       25760       dropout_1[0][0]
# __________________________________________________________________________________________________
# add (Add)                       (None, 1)            0           dense_4[0][0]
#                                                                  multiply[0][0]
# __________________________________________________________________________________________________
# multiply_1 (Multiply)           (None, 1, 160)       0           dense_11[0][0]
#                                                                  dense_12[0][0]
# __________________________________________________________________________________________________
# layer_normalization (LayerNorma (None, 1)            2           add[0][0]
# __________________________________________________________________________________________________
# add_1 (Add)                     (None, 1, 160)       0           tf_op_layer_TemporalFusionTransfo
#                                                                  multiply_1[0][0]
# __________________________________________________________________________________________________
# activation_1 (Activation)       (None, 1)            0           layer_normalization[0][0]
# __________________________________________________________________________________________________
# layer_normalization_1 (LayerNor (None, 1, 160)       320         add_1[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_TemporalFusionTrans [(None, 1, 1)]       0           activation_1[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_TemporalFusionTrans [(None, 1, 160)]     0           layer_normalization_1[0][0]
# __________________________________________________________________________________________________
# multiply_2 (Multiply)           (None, 1, 160)       0           tf_op_layer_TemporalFusionTransfo
#                                                                  tf_op_layer_TemporalFusionTransfo
# __________________________________________________________________________________________________
# tf_op_layer_TemporalFusionTrans [(None, 160)]        0           multiply_2[0][0]
# __________________________________________________________________________________________________
# dense_13 (Dense)                (None, 160)          25760       tf_op_layer_TemporalFusionTransfo
# __________________________________________________________________________________________________
# activation_3 (Activation)       (None, 160)          0           dense_13[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_TemporalFusionTrans [(None, 192, 4)]     0           input_1[0][0]
# __________________________________________________________________________________________________
# dense_14 (Dense)                (None, 160)          25760       activation_3[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_TemporalFusionTrans [(None, 192, 1)]     0           tf_op_layer_TemporalFusionTransfo
# __________________________________________________________________________________________________
# tf_op_layer_TemporalFusionTrans [(None, 192, 1)]     0           tf_op_layer_TemporalFusionTransfo
# __________________________________________________________________________________________________
# tf_op_layer_TemporalFusionTrans [(None, 192, 1)]     0           tf_op_layer_TemporalFusionTransfo
# __________________________________________________________________________________________________
# tf_op_layer_TemporalFusionTrans [(None, 192, 1)]     0           tf_op_layer_TemporalFusionTransfo
# __________________________________________________________________________________________________
# dropout_2 (Dropout)             (None, 160)          0           dense_14[0][0]
# __________________________________________________________________________________________________
# time_distributed_1 (TimeDistrib (None, 192, 160)     320         tf_op_layer_TemporalFusionTransfo
# __________________________________________________________________________________________________
# time_distributed_2 (TimeDistrib (None, 192, 160)     320         tf_op_layer_TemporalFusionTransfo
# __________________________________________________________________________________________________
# time_distributed_3 (TimeDistrib (None, 192, 160)     320         tf_op_layer_TemporalFusionTransfo
# __________________________________________________________________________________________________
# time_distributed (TimeDistribut (None, 192, 160)     320         tf_op_layer_TemporalFusionTransfo
# __________________________________________________________________________________________________
# dense_15 (Dense)                (None, 160)          25760       dropout_2[0][0]
# __________________________________________________________________________________________________
# dense_16 (Dense)                (None, 160)          25760       dropout_2[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_TemporalFusionTrans [(None, 192, 160, 3) 0           time_distributed_1[0][0]
#                                                                  time_distributed_2[0][0]
#                                                                  time_distributed_3[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_TemporalFusionTrans [(None, 192, 160, 1) 0           time_distributed[0][0]
# __________________________________________________________________________________________________
# multiply_3 (Multiply)           (None, 160)          0           dense_15[0][0]
#                                                                  dense_16[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_TemporalFusionTrans [(None, 168, 160, 3) 0           tf_op_layer_TemporalFusionTransfo
# __________________________________________________________________________________________________
# tf_op_layer_TemporalFusionTrans [(None, 168, 160, 1) 0           tf_op_layer_TemporalFusionTransfo
# __________________________________________________________________________________________________
# add_2 (Add)                     (None, 160)          0           tf_op_layer_TemporalFusionTransfo
#                                                                  multiply_3[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_TemporalFusionTrans [(None, 168, 160, 4) 0           tf_op_layer_TemporalFusionTransfo
#                                                                  tf_op_layer_TemporalFusionTransfo
# __________________________________________________________________________________________________
# layer_normalization_2 (LayerNor (None, 160)          320         add_2[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_TemporalFusionTrans [(None, 168, 640)]   0           tf_op_layer_TemporalFusionTransfo
# __________________________________________________________________________________________________
# tf_op_layer_TemporalFusionTrans [(None, 1, 160)]     0           layer_normalization_2[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_TemporalFusionTrans [(None, 24, 160, 3)] 0           tf_op_layer_TemporalFusionTransfo
# __________________________________________________________________________________________________
# time_distributed_5 (TimeDistrib (None, 168, 160)     102560      tf_op_layer_TemporalFusionTransfo
# __________________________________________________________________________________________________
# time_distributed_6 (TimeDistrib (None, 1, 160)       25600       tf_op_layer_TemporalFusionTransfo
# __________________________________________________________________________________________________
# tf_op_layer_TemporalFusionTrans [(None, 24, 480)]    0           tf_op_layer_TemporalFusionTransfo
# __________________________________________________________________________________________________
# tf_op_layer_TemporalFusionTrans [(None, 1, 160)]     0           layer_normalization_2[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_TemporalFusionTrans [(None, 168, 160)]   0           time_distributed_5[0][0]
#                                                                  time_distributed_6[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_TemporalFusionTrans [(None, 168, 160)]   0           tf_op_layer_TemporalFusionTransfo
# __________________________________________________________________________________________________
# tf_op_layer_TemporalFusionTrans [(None, 168, 160)]   0           tf_op_layer_TemporalFusionTransfo
# __________________________________________________________________________________________________
# tf_op_layer_TemporalFusionTrans [(None, 168, 160)]   0           tf_op_layer_TemporalFusionTransfo
# __________________________________________________________________________________________________
# tf_op_layer_TemporalFusionTrans [(None, 168, 160)]   0           tf_op_layer_TemporalFusionTransfo
# __________________________________________________________________________________________________
# time_distributed_27 (TimeDistri (None, 24, 160)      76960       tf_op_layer_TemporalFusionTransfo
# __________________________________________________________________________________________________
# time_distributed_28 (TimeDistri (None, 1, 160)       25600       tf_op_layer_TemporalFusionTransfo
# __________________________________________________________________________________________________
# activation_7 (Activation)       (None, 168, 160)     0           tf_op_layer_TemporalFusionTransfo
# __________________________________________________________________________________________________
# time_distributed_10 (TimeDistri (None, 168, 160)     25760       tf_op_layer_TemporalFusionTransfo
# __________________________________________________________________________________________________
# time_distributed_14 (TimeDistri (None, 168, 160)     25760       tf_op_layer_TemporalFusionTransfo
# __________________________________________________________________________________________________
# time_distributed_18 (TimeDistri (None, 168, 160)     25760       tf_op_layer_TemporalFusionTransfo
# __________________________________________________________________________________________________
# time_distributed_22 (TimeDistri (None, 168, 160)     25760       tf_op_layer_TemporalFusionTransfo
# __________________________________________________________________________________________________
# tf_op_layer_TemporalFusionTrans [(None, 24, 160)]    0           time_distributed_27[0][0]
#                                                                  time_distributed_28[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_TemporalFusionTrans [(None, 24, 160)]    0           tf_op_layer_TemporalFusionTransfo
# __________________________________________________________________________________________________
# tf_op_layer_TemporalFusionTrans [(None, 24, 160)]    0           tf_op_layer_TemporalFusionTransfo
# __________________________________________________________________________________________________
# tf_op_layer_TemporalFusionTrans [(None, 24, 160)]    0           tf_op_layer_TemporalFusionTransfo
# __________________________________________________________________________________________________
# time_distributed_7 (TimeDistrib (None, 168, 160)     25760       activation_7[0][0]
# __________________________________________________________________________________________________
# activation_9 (Activation)       (None, 168, 160)     0           time_distributed_10[0][0]
# __________________________________________________________________________________________________
# activation_10 (Activation)      (None, 168, 160)     0           time_distributed_14[0][0]
# __________________________________________________________________________________________________
# activation_11 (Activation)      (None, 168, 160)     0           time_distributed_18[0][0]
# __________________________________________________________________________________________________
# activation_12 (Activation)      (None, 168, 160)     0           time_distributed_22[0][0]
# __________________________________________________________________________________________________
# activation_13 (Activation)      (None, 24, 160)      0           tf_op_layer_TemporalFusionTransfo
# __________________________________________________________________________________________________
# time_distributed_32 (TimeDistri (None, 24, 160)      25760       tf_op_layer_TemporalFusionTransfo
# __________________________________________________________________________________________________
# time_distributed_36 (TimeDistri (None, 24, 160)      25760       tf_op_layer_TemporalFusionTransfo
# __________________________________________________________________________________________________
# time_distributed_40 (TimeDistri (None, 24, 160)      25760       tf_op_layer_TemporalFusionTransfo
# __________________________________________________________________________________________________
# dropout_6 (Dropout)             (None, 168, 160)     0           time_distributed_7[0][0]
# __________________________________________________________________________________________________
# time_distributed_11 (TimeDistri (None, 168, 160)     25760       activation_9[0][0]
# __________________________________________________________________________________________________
# time_distributed_15 (TimeDistri (None, 168, 160)     25760       activation_10[0][0]
# __________________________________________________________________________________________________
# time_distributed_19 (TimeDistri (None, 168, 160)     25760       activation_11[0][0]
# __________________________________________________________________________________________________
# time_distributed_23 (TimeDistri (None, 168, 160)     25760       activation_12[0][0]
# __________________________________________________________________________________________________
# time_distributed_29 (TimeDistri (None, 24, 160)      25760       activation_13[0][0]
# __________________________________________________________________________________________________
# activation_15 (Activation)      (None, 24, 160)      0           time_distributed_32[0][0]
# __________________________________________________________________________________________________
# activation_16 (Activation)      (None, 24, 160)      0           time_distributed_36[0][0]
# __________________________________________________________________________________________________
# activation_17 (Activation)      (None, 24, 160)      0           time_distributed_40[0][0]
# __________________________________________________________________________________________________
# time_distributed_8 (TimeDistrib (None, 168, 4)       644         dropout_6[0][0]
# __________________________________________________________________________________________________
# time_distributed_9 (TimeDistrib (None, 168, 4)       644         dropout_6[0][0]
# __________________________________________________________________________________________________
# dropout_7 (Dropout)             (None, 168, 160)     0           time_distributed_11[0][0]
# __________________________________________________________________________________________________
# dropout_8 (Dropout)             (None, 168, 160)     0           time_distributed_15[0][0]
# __________________________________________________________________________________________________
# dropout_9 (Dropout)             (None, 168, 160)     0           time_distributed_19[0][0]
# __________________________________________________________________________________________________
# dropout_10 (Dropout)            (None, 168, 160)     0           time_distributed_23[0][0]
# __________________________________________________________________________________________________
# dense_21 (Dense)                (None, 160)          25760       tf_op_layer_TemporalFusionTransfo
# __________________________________________________________________________________________________
# dense_25 (Dense)                (None, 160)          25760       tf_op_layer_TemporalFusionTransfo
# __________________________________________________________________________________________________
# dropout_11 (Dropout)            (None, 24, 160)      0           time_distributed_29[0][0]
# __________________________________________________________________________________________________
# time_distributed_33 (TimeDistri (None, 24, 160)      25760       activation_15[0][0]
# __________________________________________________________________________________________________
# time_distributed_37 (TimeDistri (None, 24, 160)      25760       activation_16[0][0]
# __________________________________________________________________________________________________
# time_distributed_41 (TimeDistri (None, 24, 160)      25760       activation_17[0][0]
# __________________________________________________________________________________________________
# time_distributed_4 (TimeDistrib (None, 168, 4)       2564        tf_op_layer_TemporalFusionTransfo
# __________________________________________________________________________________________________
# multiply_7 (Multiply)           (None, 168, 4)       0           time_distributed_8[0][0]
#                                                                  time_distributed_9[0][0]
# __________________________________________________________________________________________________
# time_distributed_12 (TimeDistri (None, 168, 160)     25760       dropout_7[0][0]
# __________________________________________________________________________________________________
# time_distributed_13 (TimeDistri (None, 168, 160)     25760       dropout_7[0][0]
# __________________________________________________________________________________________________
# time_distributed_16 (TimeDistri (None, 168, 160)     25760       dropout_8[0][0]
# __________________________________________________________________________________________________
# time_distributed_17 (TimeDistri (None, 168, 160)     25760       dropout_8[0][0]
# __________________________________________________________________________________________________
# time_distributed_20 (TimeDistri (None, 168, 160)     25760       dropout_9[0][0]
# __________________________________________________________________________________________________
# time_distributed_21 (TimeDistri (None, 168, 160)     25760       dropout_9[0][0]
# __________________________________________________________________________________________________
# time_distributed_24 (TimeDistri (None, 168, 160)     25760       dropout_10[0][0]
# __________________________________________________________________________________________________
# time_distributed_25 (TimeDistri (None, 168, 160)     25760       dropout_10[0][0]
# __________________________________________________________________________________________________
# activation_5 (Activation)       (None, 160)          0           dense_21[0][0]
# __________________________________________________________________________________________________
# activation_6 (Activation)       (None, 160)          0           dense_25[0][0]
# __________________________________________________________________________________________________
# time_distributed_30 (TimeDistri (None, 24, 3)        483         dropout_11[0][0]
# __________________________________________________________________________________________________
# time_distributed_31 (TimeDistri (None, 24, 3)        483         dropout_11[0][0]
# __________________________________________________________________________________________________
# dropout_12 (Dropout)            (None, 24, 160)      0           time_distributed_33[0][0]
# __________________________________________________________________________________________________
# dropout_13 (Dropout)            (None, 24, 160)      0           time_distributed_37[0][0]
# __________________________________________________________________________________________________
# dropout_14 (Dropout)            (None, 24, 160)      0           time_distributed_41[0][0]
# __________________________________________________________________________________________________
# add_6 (Add)                     (None, 168, 4)       0           time_distributed_4[0][0]
#                                                                  multiply_7[0][0]
# __________________________________________________________________________________________________
# multiply_8 (Multiply)           (None, 168, 160)     0           time_distributed_12[0][0]
#                                                                  time_distributed_13[0][0]
# __________________________________________________________________________________________________
# multiply_9 (Multiply)           (None, 168, 160)     0           time_distributed_16[0][0]
#                                                                  time_distributed_17[0][0]
# __________________________________________________________________________________________________
# multiply_10 (Multiply)          (None, 168, 160)     0           time_distributed_20[0][0]
#                                                                  time_distributed_21[0][0]
# __________________________________________________________________________________________________
# multiply_11 (Multiply)          (None, 168, 160)     0           time_distributed_24[0][0]
#                                                                  time_distributed_25[0][0]
# __________________________________________________________________________________________________
# dense_22 (Dense)                (None, 160)          25760       activation_5[0][0]
# __________________________________________________________________________________________________
# dense_26 (Dense)                (None, 160)          25760       activation_6[0][0]
# __________________________________________________________________________________________________
# time_distributed_26 (TimeDistri (None, 24, 3)        1443        tf_op_layer_TemporalFusionTransfo
# __________________________________________________________________________________________________
# multiply_13 (Multiply)          (None, 24, 3)        0           time_distributed_30[0][0]
#                                                                  time_distributed_31[0][0]
# __________________________________________________________________________________________________
# time_distributed_34 (TimeDistri (None, 24, 160)      25760       dropout_12[0][0]
# __________________________________________________________________________________________________
# time_distributed_35 (TimeDistri (None, 24, 160)      25760       dropout_12[0][0]
# __________________________________________________________________________________________________
# time_distributed_38 (TimeDistri (None, 24, 160)      25760       dropout_13[0][0]
# __________________________________________________________________________________________________
# time_distributed_39 (TimeDistri (None, 24, 160)      25760       dropout_13[0][0]
# __________________________________________________________________________________________________
# time_distributed_42 (TimeDistri (None, 24, 160)      25760       dropout_14[0][0]
# __________________________________________________________________________________________________
# time_distributed_43 (TimeDistri (None, 24, 160)      25760       dropout_14[0][0]
# __________________________________________________________________________________________________
# layer_normalization_6 (LayerNor (None, 168, 4)       8           add_6[0][0]
# __________________________________________________________________________________________________
# add_7 (Add)                     (None, 168, 160)     0           tf_op_layer_TemporalFusionTransfo
#                                                                  multiply_8[0][0]
# __________________________________________________________________________________________________
# add_8 (Add)                     (None, 168, 160)     0           tf_op_layer_TemporalFusionTransfo
#                                                                  multiply_9[0][0]
# __________________________________________________________________________________________________
# add_9 (Add)                     (None, 168, 160)     0           tf_op_layer_TemporalFusionTransfo
#                                                                  multiply_10[0][0]
# __________________________________________________________________________________________________
# add_10 (Add)                    (None, 168, 160)     0           tf_op_layer_TemporalFusionTransfo
#                                                                  multiply_11[0][0]
# __________________________________________________________________________________________________
# dropout_4 (Dropout)             (None, 160)          0           dense_22[0][0]
# __________________________________________________________________________________________________
# dropout_5 (Dropout)             (None, 160)          0           dense_26[0][0]
# __________________________________________________________________________________________________
# add_11 (Add)                    (None, 24, 3)        0           time_distributed_26[0][0]
#                                                                  multiply_13[0][0]
# __________________________________________________________________________________________________
# multiply_14 (Multiply)          (None, 24, 160)      0           time_distributed_34[0][0]
#                                                                  time_distributed_35[0][0]
# __________________________________________________________________________________________________
# multiply_15 (Multiply)          (None, 24, 160)      0           time_distributed_38[0][0]
#                                                                  time_distributed_39[0][0]
# __________________________________________________________________________________________________
# multiply_16 (Multiply)          (None, 24, 160)      0           time_distributed_42[0][0]
#                                                                  time_distributed_43[0][0]
# __________________________________________________________________________________________________
# activation_8 (Activation)       (None, 168, 4)       0           layer_normalization_6[0][0]
# __________________________________________________________________________________________________
# layer_normalization_7 (LayerNor (None, 168, 160)     320         add_7[0][0]
# __________________________________________________________________________________________________
# layer_normalization_8 (LayerNor (None, 168, 160)     320         add_8[0][0]
# __________________________________________________________________________________________________
# layer_normalization_9 (LayerNor (None, 168, 160)     320         add_9[0][0]
# __________________________________________________________________________________________________
# layer_normalization_10 (LayerNo (None, 168, 160)     320         add_10[0][0]
# __________________________________________________________________________________________________
# dense_23 (Dense)                (None, 160)          25760       dropout_4[0][0]
# __________________________________________________________________________________________________
# dense_24 (Dense)                (None, 160)          25760       dropout_4[0][0]
# __________________________________________________________________________________________________
# dense_27 (Dense)                (None, 160)          25760       dropout_5[0][0]
# __________________________________________________________________________________________________
# dense_28 (Dense)                (None, 160)          25760       dropout_5[0][0]
# __________________________________________________________________________________________________
# layer_normalization_11 (LayerNo (None, 24, 3)        6           add_11[0][0]
# __________________________________________________________________________________________________
# add_12 (Add)                    (None, 24, 160)      0           tf_op_layer_TemporalFusionTransfo
#                                                                  multiply_14[0][0]
# __________________________________________________________________________________________________
# add_13 (Add)                    (None, 24, 160)      0           tf_op_layer_TemporalFusionTransfo
#                                                                  multiply_15[0][0]
# __________________________________________________________________________________________________
# add_14 (Add)                    (None, 24, 160)      0           tf_op_layer_TemporalFusionTransfo
#                                                                  multiply_16[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_TemporalFusionTrans [(None, 168, 1, 4)]  0           activation_8[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_TemporalFusionTrans [(None, 168, 160, 4) 0           layer_normalization_7[0][0]
#                                                                  layer_normalization_8[0][0]
#                                                                  layer_normalization_9[0][0]
#                                                                  layer_normalization_10[0][0]
# __________________________________________________________________________________________________
# multiply_5 (Multiply)           (None, 160)          0           dense_23[0][0]
#                                                                  dense_24[0][0]
# __________________________________________________________________________________________________
# multiply_6 (Multiply)           (None, 160)          0           dense_27[0][0]
#                                                                  dense_28[0][0]
# __________________________________________________________________________________________________
# activation_14 (Activation)      (None, 24, 3)        0           layer_normalization_11[0][0]
# __________________________________________________________________________________________________
# layer_normalization_12 (LayerNo (None, 24, 160)      320         add_12[0][0]
# __________________________________________________________________________________________________
# layer_normalization_13 (LayerNo (None, 24, 160)      320         add_13[0][0]
# __________________________________________________________________________________________________
# layer_normalization_14 (LayerNo (None, 24, 160)      320         add_14[0][0]
# __________________________________________________________________________________________________
# multiply_12 (Multiply)          (None, 168, 160, 4)  0           tf_op_layer_TemporalFusionTransfo
#                                                                  tf_op_layer_TemporalFusionTransfo
# __________________________________________________________________________________________________
# add_4 (Add)                     (None, 160)          0           tf_op_layer_TemporalFusionTransfo
#                                                                  multiply_5[0][0]
# __________________________________________________________________________________________________
# add_5 (Add)                     (None, 160)          0           tf_op_layer_TemporalFusionTransfo
#                                                                  multiply_6[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_TemporalFusionTrans [(None, 24, 1, 3)]   0           activation_14[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_TemporalFusionTrans [(None, 24, 160, 3)] 0           layer_normalization_12[0][0]
#                                                                  layer_normalization_13[0][0]
#                                                                  layer_normalization_14[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_TemporalFusionTrans [(None, 168, 160)]   0           multiply_12[0][0]
# __________________________________________________________________________________________________
# layer_normalization_4 (LayerNor (None, 160)          320         add_4[0][0]
# __________________________________________________________________________________________________
# layer_normalization_5 (LayerNor (None, 160)          320         add_5[0][0]
# __________________________________________________________________________________________________
# multiply_17 (Multiply)          (None, 24, 160, 3)   0           tf_op_layer_TemporalFusionTransfo
#                                                                  tf_op_layer_TemporalFusionTransfo
# __________________________________________________________________________________________________
# dense_17 (Dense)                (None, 160)          25760       tf_op_layer_TemporalFusionTransfo
# __________________________________________________________________________________________________
# lstm (LSTM)                     [(None, 168, 160), ( 205440      tf_op_layer_TemporalFusionTransfo
#                                                                  layer_normalization_4[0][0]
#                                                                  layer_normalization_5[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_TemporalFusionTrans [(None, 24, 160)]    0           multiply_17[0][0]
# __________________________________________________________________________________________________
# activation_4 (Activation)       (None, 160)          0           dense_17[0][0]
# __________________________________________________________________________________________________
# lstm_1 (LSTM)                   (None, 24, 160)      205440      tf_op_layer_TemporalFusionTransfo
#                                                                  lstm[0][1]
#                                                                  lstm[0][2]
# __________________________________________________________________________________________________
# dense_18 (Dense)                (None, 160)          25760       activation_4[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_TemporalFusionTrans [(None, 192, 160)]   0           lstm[0][0]
#                                                                  lstm_1[0][0]
# __________________________________________________________________________________________________
# dropout_3 (Dropout)             (None, 160)          0           dense_18[0][0]
# __________________________________________________________________________________________________
# dropout_15 (Dropout)            (None, 192, 160)     0           tf_op_layer_TemporalFusionTransfo
# __________________________________________________________________________________________________
# dense_19 (Dense)                (None, 160)          25760       dropout_3[0][0]
# __________________________________________________________________________________________________
# dense_20 (Dense)                (None, 160)          25760       dropout_3[0][0]
# __________________________________________________________________________________________________
# time_distributed_44 (TimeDistri (None, 192, 160)     25760       dropout_15[0][0]
# __________________________________________________________________________________________________
# time_distributed_45 (TimeDistri (None, 192, 160)     25760       dropout_15[0][0]
# __________________________________________________________________________________________________
# multiply_4 (Multiply)           (None, 160)          0           dense_19[0][0]
#                                                                  dense_20[0][0]
# __________________________________________________________________________________________________
# multiply_18 (Multiply)          (None, 192, 160)     0           time_distributed_44[0][0]
#                                                                  time_distributed_45[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_TemporalFusionTrans [(None, 192, 160)]   0           tf_op_layer_TemporalFusionTransfo
#                                                                  tf_op_layer_TemporalFusionTransfo
# __________________________________________________________________________________________________
# add_3 (Add)                     (None, 160)          0           tf_op_layer_TemporalFusionTransfo
#                                                                  multiply_4[0][0]
# __________________________________________________________________________________________________
# add_15 (Add)                    (None, 192, 160)     0           multiply_18[0][0]
#                                                                  tf_op_layer_TemporalFusionTransfo
# __________________________________________________________________________________________________
# layer_normalization_3 (LayerNor (None, 160)          320         add_3[0][0]
# __________________________________________________________________________________________________
# layer_normalization_15 (LayerNo (None, 192, 160)     320         add_15[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_TemporalFusionTrans [(None, 1, 160)]     0           layer_normalization_3[0][0]
# __________________________________________________________________________________________________
# time_distributed_46 (TimeDistri (None, 192, 160)     25760       layer_normalization_15[0][0]
# __________________________________________________________________________________________________
# time_distributed_47 (TimeDistri (None, 1, 160)       25600       tf_op_layer_TemporalFusionTransfo
# __________________________________________________________________________________________________
# tf_op_layer_TemporalFusionTrans [(None, 192, 160)]   0           time_distributed_46[0][0]
#                                                                  time_distributed_47[0][0]
# __________________________________________________________________________________________________
# activation_18 (Activation)      (None, 192, 160)     0           tf_op_layer_TemporalFusionTransfo
# __________________________________________________________________________________________________
# time_distributed_48 (TimeDistri (None, 192, 160)     25760       activation_18[0][0]
# ...
# __________________________________________________________________________________________________
# tf_op_layer_TemporalFusionTrans [(2,)]               0           tf_op_layer_TemporalFusionTransfo
#                                                                  tf_op_layer_TemporalFusionTransfo
# __________________________________________________________________________________________________
# tf_op_layer_TemporalFusionTrans [(None, None)]       0           tf_op_layer_TemporalFusionTransfo
# __________________________________________________________________________________________________
# tf_op_layer_TemporalFusionTrans [(None, None, None)] 0           tf_op_layer_TemporalFusionTransfo
# __________________________________________________________________________________________________
# dense_77 (Dense)                (None, 192, 40)      6400        layer_normalization_16[0][0]
# __________________________________________________________________________________________________
# dense_78 (Dense)                (None, 192, 40)      6400        layer_normalization_16[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_TemporalFusionTrans [(None, None, None)] 0           tf_op_layer_TemporalFusionTransfo
# __________________________________________________________________________________________________
# dense_79 (Dense)                (None, 192, 40)      6400        layer_normalization_16[0][0]
# __________________________________________________________________________________________________
# dense_80 (Dense)                (None, 192, 40)      6400        layer_normalization_16[0][0]
# __________________________________________________________________________________________________
# dense_81 (Dense)                (None, 192, 40)      6400        layer_normalization_16[0][0]
# __________________________________________________________________________________________________
# dense_82 (Dense)                (None, 192, 40)      6400        layer_normalization_16[0][0]
# __________________________________________________________________________________________________
# dense_83 (Dense)                (None, 192, 40)      6400        layer_normalization_16[0][0]
# __________________________________________________________________________________________________
# dense_84 (Dense)                (None, 192, 40)      6400        layer_normalization_16[0][0]
# __________________________________________________________________________________________________
# lambda (Lambda)                 (None, 192, 192)     0           dense_77[0][0]
#                                                                  dense_78[0][0]
# __________________________________________________________________________________________________
# lambda_1 (Lambda)               (None, None, None)   0           tf_op_layer_TemporalFusionTransfo
# __________________________________________________________________________________________________
# lambda_3 (Lambda)               (None, 192, 192)     0           dense_79[0][0]
#                                                                  dense_80[0][0]
# __________________________________________________________________________________________________
# lambda_4 (Lambda)               (None, None, None)   0           tf_op_layer_TemporalFusionTransfo
# __________________________________________________________________________________________________
# lambda_6 (Lambda)               (None, 192, 192)     0           dense_81[0][0]
#                                                                  dense_82[0][0]
# __________________________________________________________________________________________________
# lambda_7 (Lambda)               (None, None, None)   0           tf_op_layer_TemporalFusionTransfo
# __________________________________________________________________________________________________
# lambda_9 (Lambda)               (None, 192, 192)     0           dense_83[0][0]
#                                                                  dense_84[0][0]
# __________________________________________________________________________________________________
# lambda_10 (Lambda)              (None, None, None)   0           tf_op_layer_TemporalFusionTransfo
# __________________________________________________________________________________________________
# add_17 (Add)                    (None, 192, 192)     0           lambda[0][0]
#                                                                  lambda_1[0][0]
# __________________________________________________________________________________________________
# add_18 (Add)                    (None, 192, 192)     0           lambda_3[0][0]
#                                                                  lambda_4[0][0]
# __________________________________________________________________________________________________
# add_19 (Add)                    (None, 192, 192)     0           lambda_6[0][0]
#                                                                  lambda_7[0][0]
# __________________________________________________________________________________________________
# add_20 (Add)                    (None, 192, 192)     0           lambda_9[0][0]
#                                                                  lambda_10[0][0]
# __________________________________________________________________________________________________
# activation_19 (Activation)      (None, 192, 192)     0           add_17[0][0]
#                                                                  add_18[0][0]
#                                                                  add_19[0][0]
#                                                                  add_20[0][0]
# __________________________________________________________________________________________________
# dropout_17 (Dropout)            (None, 192, 192)     0           activation_19[0][0]
#                                                                  activation_19[1][0]
#                                                                  activation_19[2][0]
#                                                                  activation_19[3][0]
# __________________________________________________________________________________________________
# dense_76 (Dense)                (None, 192, 40)      6400        layer_normalization_16[0][0]
#                                                                  layer_normalization_16[0][0]
#                                                                  layer_normalization_16[0][0]
#                                                                  layer_normalization_16[0][0]
# __________________________________________________________________________________________________
# lambda_2 (Lambda)               (None, 192, 40)      0           dropout_17[0][0]
#                                                                  dense_76[0][0]
# __________________________________________________________________________________________________
# lambda_5 (Lambda)               (None, 192, 40)      0           dropout_17[1][0]
#                                                                  dense_76[1][0]
# __________________________________________________________________________________________________
# lambda_8 (Lambda)               (None, 192, 40)      0           dropout_17[2][0]
#                                                                  dense_76[2][0]
# __________________________________________________________________________________________________
# lambda_11 (Lambda)              (None, 192, 40)      0           dropout_17[3][0]
#                                                                  dense_76[3][0]
# __________________________________________________________________________________________________
# dropout_18 (Dropout)            (None, 192, 40)      0           lambda_2[0][0]
# __________________________________________________________________________________________________
# dropout_19 (Dropout)            (None, 192, 40)      0           lambda_5[0][0]
# __________________________________________________________________________________________________
# dropout_20 (Dropout)            (None, 192, 40)      0           lambda_8[0][0]
# __________________________________________________________________________________________________
# dropout_21 (Dropout)            (None, 192, 40)      0           lambda_11[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_TemporalFusionTrans [(4, None, 192, 40)] 0           dropout_18[0][0]
#                                                                  dropout_19[0][0]
#                                                                  dropout_20[0][0]
#                                                                  dropout_21[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_TemporalFusionTrans [(None, 192, 40)]    0           tf_op_layer_TemporalFusionTransfo
# __________________________________________________________________________________________________
# dense_85 (Dense)                (None, 192, 160)     6400        tf_op_layer_TemporalFusionTransfo
# __________________________________________________________________________________________________
# dropout_22 (Dropout)            (None, 192, 160)     0           dense_85[0][0]
# __________________________________________________________________________________________________
# dropout_23 (Dropout)            (None, 192, 160)     0           dropout_22[0][0]
# __________________________________________________________________________________________________
# time_distributed_51 (TimeDistri (None, 192, 160)     25760       dropout_23[0][0]
# __________________________________________________________________________________________________
# time_distributed_52 (TimeDistri (None, 192, 160)     25760       dropout_23[0][0]
# __________________________________________________________________________________________________
# multiply_20 (Multiply)          (None, 192, 160)     0           time_distributed_51[0][0]
#                                                                  time_distributed_52[0][0]
# __________________________________________________________________________________________________
# add_21 (Add)                    (None, 192, 160)     0           multiply_20[0][0]
#                                                                  layer_normalization_16[0][0]
# __________________________________________________________________________________________________
# layer_normalization_17 (LayerNo (None, 192, 160)     320         add_21[0][0]
# __________________________________________________________________________________________________
# time_distributed_53 (TimeDistri (None, 192, 160)     25760       layer_normalization_17[0][0]
# __________________________________________________________________________________________________
# activation_20 (Activation)      (None, 192, 160)     0           time_distributed_53[0][0]
# __________________________________________________________________________________________________
# time_distributed_54 (TimeDistri (None, 192, 160)     25760       activation_20[0][0]
# __________________________________________________________________________________________________
# dropout_24 (Dropout)            (None, 192, 160)     0           time_distributed_54[0][0]
# __________________________________________________________________________________________________
# time_distributed_55 (TimeDistri (None, 192, 160)     25760       dropout_24[0][0]
# __________________________________________________________________________________________________
# time_distributed_56 (TimeDistri (None, 192, 160)     25760       dropout_24[0][0]
# __________________________________________________________________________________________________
# multiply_21 (Multiply)          (None, 192, 160)     0           time_distributed_55[0][0]
#                                                                  time_distributed_56[0][0]
# __________________________________________________________________________________________________
# add_22 (Add)                    (None, 192, 160)     0           layer_normalization_17[0][0]
#                                                                  multiply_21[0][0]
# __________________________________________________________________________________________________
# layer_normalization_18 (LayerNo (None, 192, 160)     320         add_22[0][0]
# __________________________________________________________________________________________________
# time_distributed_57 (TimeDistri (None, 192, 160)     25760       layer_normalization_18[0][0]
# __________________________________________________________________________________________________
# time_distributed_58 (TimeDistri (None, 192, 160)     25760       layer_normalization_18[0][0]
# __________________________________________________________________________________________________
# multiply_22 (Multiply)          (None, 192, 160)     0           time_distributed_57[0][0]
#                                                                  time_distributed_58[0][0]
# __________________________________________________________________________________________________
# add_23 (Add)                    (None, 192, 160)     0           multiply_22[0][0]
#                                                                  layer_normalization_15[0][0]
# __________________________________________________________________________________________________
# layer_normalization_19 (LayerNo (None, 192, 160)     320         add_23[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_TemporalFusionTrans [(None, 24, 160)]    0           layer_normalization_19[0][0]
# __________________________________________________________________________________________________
# time_distributed_59 (TimeDistri (None, 24, 3)        483         tf_op_layer_TemporalFusionTransfo
# ==================================================================================================
# Total params: 2,504,363
# Trainable params: 2,504,363
# Non-trainable params: 0
# __________________________________________________________________________________________________
# None
# Computing test loss
# C:\Users\Lorenzo\PycharmProjects\TFT\venv\lib\site-packages\tensorflow\python\keras\engine\training.py:2325: UserWarning: `Model.state_updates` will be removed in a future version. This property should not be used in TensorFlow 2.0, as `updates` are applied automatically.
#   warnings.warn('`Model.state_updates` will be removed in a future version. '
# Output map returned a dict with keys (53505, 26)
# saving predictions and targets
#
# Normalised Quantile Loss for Test Data: P50=0.06195225913111236, P90=0.03087768990980622

# %% [markdown]
# # UNDERSTANDING SAVED PREDICTIONS

# %%
p50_forecast: DataFrame = pd.read_csv(os.path.join(opt_manager.hyperparam_folder, "p50.csv"))
p90_forecast: DataFrame = pd.read_csv(os.path.join(opt_manager.hyperparam_folder, "p90.csv"))
targets: DataFrame = pd.read_csv(os.path.join(opt_manager.hyperparam_folder, "targets.csv"))

# %%
p50_forecast.head()
# Out:
#          forecast_time identifier        t+0        t+1        t+2        t+3  \
# 0  2014-08-31 23:00:00     MT_001  15.816484  15.426067  15.101756  15.059324
# 1  2014-09-01 00:00:00     MT_001  15.801899  15.549843  15.710974  15.848249
# 2  2014-09-01 01:00:00     MT_001  15.713786  15.589179  15.790873  15.575740
# 3  2014-09-01 02:00:00     MT_001  15.564478  15.574275  15.491813  15.173822
# 4  2014-09-01 03:00:00     MT_001  15.549872  15.505312  15.312562  15.243621
#
#          t+4        t+5        t+6        t+7  ...       t+14       t+15  \
# 0  15.272384  15.324549  15.201153  14.856417  ...  15.984920  15.557263
# 1  15.672518  15.450286  15.230310  15.300977  ...  16.338890  16.242607
# 2  15.245438  15.128947  15.345088  16.095377  ...  16.383362  16.368664
# 3  15.081623  15.429429  16.036526  16.302347  ...  16.403620  15.569962
# 4  15.582037  16.077026  16.343262  16.521887  ...  15.632707  16.093567
#
#         t+16       t+17       t+18       t+19       t+20       t+21  \
# 0  15.629363  16.073324  15.508624  15.737225  15.264067  15.972996
# 1  16.346140  15.416276  16.004236  15.562339  16.733631  16.430775
# 2  15.480453  16.182049  15.862064  17.132368  16.359085  15.914165
# 3  16.122433  15.804259  17.137283  16.351220  15.906891  16.543669
# 4  15.772758  17.056166  16.343170  15.808394  16.562973  15.204091
#
#         t+22       t+23
# 0  16.565828  15.223506
# 1  15.576667  16.253613
# 2  16.430271  15.312605
# 3  15.254826  14.968862
# 4  14.902324  14.493794
#
# [5 rows x 26 columns]

# %%
targets.head()
# Out:
#          forecast_time identifier        t+0        t+1        t+2        t+3  \
# 0  2014-08-31 23:00:00     MT_001  16.180203  16.497462  16.180203  16.497462
# 1  2014-09-01 00:00:00     MT_001  16.497462  16.180203  16.497462  16.180203
# 2  2014-09-01 01:00:00     MT_001  16.180203  16.497462  16.180203  16.814721
# 3  2014-09-01 02:00:00     MT_001  16.497462  16.180203  16.814721  16.497462
# 4  2014-09-01 03:00:00     MT_001  16.180203  16.814721  16.497462  22.208122
#
#          t+4        t+5        t+6        t+7  ...       t+14       t+15  \
# 0  16.180203  16.814721  16.497462  22.208122  ...  14.911168  14.593909
# 1  16.814721  16.497462  22.208122  14.911168  ...  14.593909  14.911168
# 2  16.497462  22.208122  14.911168  21.890863  ...  14.911168  15.228426
# 3  22.208122  14.911168  21.890863  14.593909  ...  15.228426  16.180203
# 4  14.911168  21.890863  14.593909  14.911168  ...  16.180203   9.517766
#
#         t+16       t+17       t+18       t+19       t+20       t+21  \
# 0  14.911168  15.228426  16.180203   9.517766   2.855330   4.758883
# 1  15.228426  16.180203   9.517766   2.855330   4.758883  16.497462
# 2  16.180203   9.517766   2.855330   4.758883  16.497462   8.565990
# 3   9.517766   2.855330   4.758883  16.497462   8.565990   3.489848
# 4   2.855330   4.758883  16.497462   8.565990   3.489848   3.489848
#
#         t+22      t+23
# 0  16.497462  8.565990
# 1   8.565990  3.489848
# 2   3.489848  3.489848
# 3   3.489848  3.807107
# 4   3.807107  3.489848
#
# [5 rows x 26 columns]

# %%
p90_forecast.head()
# Out:
#          forecast_time identifier        t+0        t+1        t+2        t+3  \
# 0  2014-08-31 23:00:00     MT_001  19.484957  19.966455  20.021095  20.073578
# 1  2014-09-01 00:00:00     MT_001  19.708284  19.499857  19.807434  20.135532
# 2  2014-09-01 01:00:00     MT_001  19.994995  19.905256  20.260685  20.451100
# 3  2014-09-01 02:00:00     MT_001  19.872185  19.995995  20.374674  20.395540
# 4  2014-09-01 03:00:00     MT_001  19.825720  20.178839  20.556164  20.439846
#
#          t+4        t+5        t+6        t+7  ...       t+14       t+15  \
# 0  20.247953  20.455720  20.458849  20.715023  ...  20.166730  19.837234
# 1  20.403917  20.499739  20.539919  20.892770  ...  20.518990  20.470705
# 2  20.369469  20.475649  20.877966  21.582720  ...  20.631052  20.753662
# 3  20.372040  20.982529  21.356647  21.735025  ...  20.818357  20.456345
# 4  21.130474  21.349077  21.730026  21.786488  ...  20.578382  21.732712
#
#         t+16       t+17       t+18       t+19       t+20       t+21  \
# 0  20.098585  20.942125  20.916756  21.400381  20.641865  21.257446
# 1  20.802544  20.359140  21.617046  20.859167  21.741335  20.676088
# 2  20.240032  21.627714  20.893682  21.687847  20.452843  19.897978
# 3  21.669260  20.941670  21.758282  20.560837  19.971897  20.747753
# 4  21.005820  21.820227  20.648443  19.998306  20.827150  20.363838
#
#         t+22       t+23
# 0  20.518513  19.297764
# 1  19.746414  20.406603
# 2  20.597872  20.448656
# 3  20.362760  20.168312
# 4  20.127650  20.186728
#
# [5 rows x 26 columns]

# %% [markdown]
# CHECK IF TARGETS CORRESPONDS TO RAW DATA

# %%
def test_targets(targets: DataFrame, raw_data: DataFrame, timestamp: str, identifier: str):
    """

    :param targets: targets DataFrame returned by predict method
    :param raw_data: original dataset
    :param timestamp: (str) random timestamp in dataset
    :param identifier:
    :return: None
    """
    # pick random timestamp and identifier
#     timestamp: str = random.choice(targets['forecast_time'])
#     identifier: str = random.choice(targets['identifier'])
    target_data: ndarray = targets[(targets['forecast_time'] == timestamp) & (targets['identifier'] == identifier)].iloc[:,
           2:].values
    raw: ndarray = raw_data[(raw_data['date'] >= pd.Timestamp(timestamp) + pd.Timedelta(hours=1)) & (
                                                         raw_data['date'] <= pd.Timestamp(timestamp) + pd.Timedelta(
                                                     hours=24)) & (raw_data['id'] == identifier)].iloc[:,
                                         1].values

    assert allclose(target_data, raw)

# %%
targets['identifier'].unique()[0]
# Out:
# 'MT_001'

# %%
for ts in tqdm(targets['forecast_time'].unique()):
    for i in targets['identifier'].unique():
        test_targets(targets, raw_data, ts, i)
# Out:
# 100%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 145/145 [1:55:26<00:00, 47.77s/it]

# %%
identifier = random.choice(targets['identifier'])
identifier
# Out:
# 'MT_290'

# %%
timestamp: str = '2014-08-31 23:00:00'

# %%
a = targets[(targets['forecast_time']==timestamp) & (targets['identifier']=='MT_001')].iloc[:, 2:].values

# %%
a, b
# Out:
# (array([[16.18020305, 16.49746193, 16.18020305, 16.49746193, 16.18020305,
#          16.81472081, 16.49746193, 22.20812183, 14.91116751, 21.89086294,
#          14.59390863, 14.91116751, 14.59390863, 14.59390863, 14.91116751,
#          14.59390863, 14.91116751, 15.2284264 , 16.18020305,  9.5177665 ,
#           2.85532995,  4.75888325, 16.49746193,  8.56598985]]),
#  array([16.18020305, 16.49746193, 16.18020305, 16.49746193, 16.18020305,
#         16.81472081, 16.49746193, 22.20812183, 14.91116751, 21.89086294,
#         14.59390863, 14.91116751, 14.59390863, 14.59390863, 14.91116751,
#         14.59390863, 14.91116751, 15.2284264 , 16.18020305,  9.5177665 ,
#          2.85532995,  4.75888325, 16.49746193,  8.56598985]))

# %%
b = raw_data[(raw_data['date']>=pd.Timestamp(timestamp)+pd.Timedelta(hours=1)) & (raw_data['date']<=pd.Timestamp(timestamp)+pd.Timedelta(hours=24)) & (raw_data['id']=='MT_001')].iloc[:,1].values

# %%
assert allclose(a,b, rtol=1e-50, atol=1e-100)

# %%
assert targets[(targets['forecast_time']==timestamp) & (targets['identifier']=='MT_001')].iloc[:, 2:].values.all() == raw_data[(raw_data['date']>=pd.Timestamp(timestamp)+pd.Timedelta(hours=1)) & (raw_data['date']<=pd.Timestamp(timestamp)+pd.Timedelta(hours=24)) & (raw_data['id']=='MT_001')].iloc[:,1].values.all()

# %%
# for i in tqdm(zip(targets['forecast_time'].values, targets['identifier'].values)):
#     assert targets[(targets['forecast_time']==i[0]) & (targets['identifier']==i[1])].iloc[:, 2:].values.tolist().sort() == raw_data[(raw_data['date']>=pd.Timestamp(i[0])+pd.Timedelta(hours=1)) & (raw_data['date']<=pd.Timestamp(i[0])+pd.Timedelta(hours=24)) & (raw_data['id']==i[1])].iloc[:,1].values.tolist().sort()

# %%
def checker(row: Series, targets: DataFrame, raw_data: DataFrame):
#     print(row[0], row[1])
    assert targets[(targets['forecast_time']==row[0]) & (targets['identifier']==row[1])].iloc[:, 2:].values.tolist().sort() == raw_data[(raw_data['date']>=pd.Timestamp(row[0])+pd.Timedelta(hours=1)) & (raw_data['date']<=pd.Timestamp(row[0])+pd.Timedelta(hours=24)) & (raw_data['id']==row[1])].iloc[:,1].values.tolist().sort()

# %%
# targets.apply(checker, axis=1, args=(targets, raw_data))

# %% [markdown]
# PIVOT TARGET AND PREDS

# %%
def pivot(df: DataFrame) -> DataFrame:
    df['forecast_time'] = df['forecast_time'].astype('datetime64[s]')
    df_pivot: DataFrame = df.pivot(index=['forecast_time'], columns='identifier', values=df.columns[2:].tolist())
    df_piv2 = df_pivot.stack(level=0)
    # drop multilevel index
    df_piv2 = df_piv2.reset_index(level=1, drop=False)
    # set level as a int (hourly timedelta)
    df_piv2['level_1'] = df_piv2['level_1'].str.replace('t+', '')
    df_piv2['level_1'] = df_piv2['level_1'].astype('int64')
    df_piv2['level_1'] = df_piv2['level_1'] + 1
    df_piv2.reset_index(drop=False, inplace=True)

    def add_hour(row: Series) -> Series:
        row['forecast_time'] = row['forecast_time'] + pd.Timedelta(hours=row['level_1'])

        return row

    df_piv2 = df_piv2.apply(add_hour, axis=1)
    # sort by forecast_time
    df_piv2.sort_values(by=['forecast_time'], ascending=True, inplace=True)
    df_piv2.drop(['level_1'], axis=1, inplace=True)
    # drop duplicates hours
    df_piv2.drop_duplicates(subset=['forecast_time'], inplace=True)
    df_piv2.columns.name = None
    df_piv2.reset_index(drop=True, inplace=True)

    return df_piv2

# %%
targets_piv = pivot(targets)
# Out:
# C:\Users\Lorenzo\PycharmProjects\TFT\venv\lib\site-packages\ipykernel_launcher.py:8: FutureWarning: The default value of regex will change from True to False in a future version.

# %%
targets_piv.head()
# Out:
#         forecast_time     MT_001     MT_002    MT_003      MT_004     MT_005  \
# 0 2014-09-01 00:00:00  16.180203  33.783784  1.737619  128.556911  46.341463
# 1 2014-09-01 01:00:00  16.497462  27.382646  1.737619  104.674797  42.378049
# 2 2014-09-01 02:00:00  16.180203  24.715505  1.737619   94.512195  40.243902
# 3 2014-09-01 03:00:00  16.497462  24.537696  1.520417   89.430894  37.500000
# 4 2014-09-01 04:00:00  16.180203  24.893314  1.737619   94.004065  36.280488
#
#        MT_006    MT_007      MT_008     MT_009  ...      MT_361   MT_362  \
# 0  159.970238  3.957038  218.013468  40.646853  ...  101.713062  46350.0
# 1  125.744048  3.250424  191.919192  37.150350  ...   55.496074  18600.0
# 2  117.559524  3.250424  182.659933  38.461538  ...   51.570307  17725.0
# 3  116.071429  3.250424  222.222222  38.898601  ...   51.034975  15050.0
# 4  121.279762  3.109101  201.178451  36.713287  ...   51.570307  13225.0
#
#         MT_363       MT_364     MT_365    MT_366      MT_367     MT_368  \
# 0  1000.000000  2255.681818  41.069100  9.947338  608.867428  49.666110
# 1   695.147679  1153.409091  31.616688  8.484494  618.744513  49.248748
# 2   712.025316  1113.636364  31.290743  5.412522  565.188762  52.587646
# 3   704.641350  1073.863636  31.616688  5.266238  544.117647  50.918197
# 4   704.641350   982.954545  31.290743  7.753072  538.410887  49.666110
#
#        MT_369        MT_370
# 0  766.312317  23324.324324
# 1  720.857771  23324.324324
# 2  733.687683  23554.054054
# 3  713.343109  21662.162162
# 4  720.307918  23729.729730
#
# [5 rows x 370 columns]

# %%
# timestamp_upper: str = '2014-09-01 00:00:00'
# timestamp_lower: str = (targets_piv['forecast_time'].max() - pd.Timedelta(hours=23)).strftime('%Y-%m-%d %H:%M:%S')

# %%
# raw_data[(raw_data['date']>=pd.Timestamp('2014-09-01 14:00:00')) & (raw_data['date']<=pd.Timestamp('2014-09-01 14:00:00')+pd.Timedelta(hours=23)) & (raw_data['id']=='MT_001')].iloc[:,1].values.tolist()

# %%
# targets_piv[(targets_piv['forecast_time']>=pd.Timestamp('2014-09-01 14:00:00')) & (targets_piv['forecast_time']<=pd.Timestamp('2014-09-01 14:00:00')+pd.Timedelta(hours=23))].loc[:, 'MT_001'].values.tolist()

# %%
# for timestamp in pd.date_range(start=pd.Timestamp('2014-09-01 00:00:00'), end=(targets_piv['forecast_time'].max() - pd.Timedelta(hours=23)),
#                                                   freq=pd.offsets.Hour(1)):
#     if raw_data[(raw_data['date']>=pd.Timestamp(timestamp)) & (raw_data['date']<=pd.Timestamp(timestamp)+pd.Timedelta(hours=23)) & (raw_data['id']=='MT_001')].iloc[:,1].values.tolist() == targets_piv[(targets_piv['forecast_time']>=pd.Timestamp(timestamp)) & (targets_piv['forecast_time']<=pd.Timestamp(timestamp)+pd.Timedelta(hours=23))].loc[:, 'MT_001'].values.tolist():
#         continue
#     else:
#         print(timestamp)

# %%
# targets_piv['forecast_time'].max() - pd.Timedelta(hours=23)

# %%
p50_piv: DataFrame = pivot(p50_forecast)
p90_piv: DataFrame = pivot(p90_forecast)
# Out:
# C:\Users\Lorenzo\PycharmProjects\TFT\venv\lib\site-packages\ipykernel_launcher.py:8: FutureWarning: The default value of regex will change from True to False in a future version.
#
# C:\Users\Lorenzo\PycharmProjects\TFT\venv\lib\site-packages\ipykernel_launcher.py:8: FutureWarning: The default value of regex will change from True to False in a future version.

# %%
p50_piv.head()
# Out:
#         forecast_time     MT_001     MT_002    MT_003     MT_004     MT_005  \
# 0 2014-09-01 00:00:00  15.816484  32.333202  1.726487  119.80411  47.519485
# 1 2014-09-01 01:00:00  15.426067  27.259977  1.725155   99.02534  42.097904
# 2 2014-09-01 02:00:00  15.549843  26.116793  1.544381   91.94444  38.116226
# 3 2014-09-01 03:00:00  15.710974  25.811470  1.721075   87.46027  37.200290
# 4 2014-09-01 04:00:00  15.574275  25.735700  1.731947   85.26460  37.074120
#
#       MT_006    MT_007     MT_008     MT_009  ...     MT_361     MT_362  \
# 0  143.74661  3.985144  225.68738  41.003960  ...  96.095055  29567.742
# 1  122.17685  3.487472  202.56679  41.436615  ...  45.153713  20238.367
# 2  117.20415  3.252636  198.64682  39.628800  ...  48.428480  17006.703
# 3  117.28565  3.228712  217.45206  38.950310  ...  44.072170  13547.113
# 4  114.15558  3.097564  207.18054  37.340942  ...  48.840267  11509.521
#
#        MT_363     MT_364     MT_365    MT_366     MT_367     MT_368    MT_369  \
# 0  1002.45900  2253.4258  62.161964  6.966114  643.72375  42.859077  786.4482
# 1   754.63086  1081.7880  24.938011  5.047535  599.55480  41.065666  751.6471
# 2   686.21290  1046.3827  23.602146  4.682081  551.80110  42.157806  759.3985
# 3   654.61660   970.2458  22.339233  5.593839  538.39870  45.283806  762.0596
# 4   653.29870   901.4543  22.922176  5.812411  539.22546  49.051980  738.7145
#
#       MT_370
# 0  21632.580
# 1  21268.160
# 2  21629.219
# 3  21552.654
# 4  21566.703
#
# [5 rows x 370 columns]

# %%
p50_piv.shape
# Out:
# (168, 370)

# %%
t_mt_001 = targets[targets['identifier']=='MT_001']

# %%
# check if date ranges of targets and targets_piv are the same
assert t_mt_001['forecast_time'].max() + pd.Timedelta(hours=24) == targets_piv['forecast_time'].max()
assert t_mt_001['forecast_time'].min() + pd.Timedelta(hours=1) == targets_piv['forecast_time'].min()

# %% [markdown]
# # CALCULATE MAPE

# %%
targets_piv_1 = targets_piv[['forecast_time', 'MT_001']]
p50_piv_1 = p50_piv[['forecast_time', 'MT_001']]

# %%
def rolling_mape_multitarget(targets_df: DataFrame, preds_df: DataFrame, hours_mape: int) -> DataFrame:
    count = 0
    for mt in targets_df.columns[1:]:
        if count == 0:
            df_mape: DataFrame = pd.DataFrame(data={'forecast_time': preds_df['forecast_time'], 'true': targets_df[mt], 'preds': preds_df[mt]})
            df_mape['abs(Pred-true)']: Series = np.abs(df_mape['preds'] - df_mape['true'])
            d: List = []

            for i in range(0, df_mape.shape[0] - hours_mape):
                a: int = sum(df_mape['abs(Pred-true)'][i:i + hours_mape])
                b: int = sum(df_mape['true'][i:i + hours_mape])
                c: float = 100 * a / b
                d.append(c)

            # prendere la data del inizio di intervallo
            p: List = []
            for i in range(0, df_mape.shape[0] - hours_mape):
                f: Union[str, Timestamp] = df_mape['forecast_time'].iloc[i]
                p.append(f)
            assert len(p) == len(d)

            df_mape_final: DataFrame = DataFrame(data={'time': p, f'mape_{mt}': d})
            count += 1

        else:
            df_mape: DataFrame = pd.DataFrame(data={'forecast_time': preds_df['forecast_time'], 'true': targets_df[mt], 'preds': preds_df[mt]})
            df_mape['abs(Pred-true)']: Series = np.abs(df_mape['preds'] - df_mape['true'])
            d: List = []

            for i in range(0, df_mape.shape[0] - hours_mape):
                a: int = sum(df_mape['abs(Pred-true)'][i:i + hours_mape])
                b: int = sum(df_mape['true'][i:i + hours_mape])
                c: float = 100 * a / b
                d.append(c)

            # prendere la data del inizio di intervallo
            p: List = []
            for i in range(0, df_mape.shape[0] - hours_mape):
                f: Union[str, Timestamp] = df_mape['forecast_time'].iloc[i]
                p.append(f)
            assert len(p) == len(d)

            df_mape_interim: DataFrame = DataFrame(data={'time': p, f'mape_{mt}': d})
            df_mape_final[f'mape_{mt}'] = df_mape_interim[f'mape_{mt}']
            count += 1
            
    return df_mape_final

# %%
df_mape_50: DataFrame = rolling_mape_multitarget(targets_piv, p50_piv, 84)

# %%
df_mape_50
# Out:
#                   time  mape_MT_001  mape_MT_002  mape_MT_003  mape_MT_004  \
# 0  2014-09-01 00:00:00    27.399685     5.410595     0.924466     7.122646
# 1  2014-09-01 01:00:00    27.488703     5.379870     0.925396     7.076477
# 2  2014-09-01 02:00:00    27.580430     5.413469     0.925799     7.261482
# 3  2014-09-01 03:00:00    27.648387     5.360905     0.797433     7.288275
# 4  2014-09-01 04:00:00    28.481666     5.377088     0.661130     7.283050
# ..                 ...          ...          ...          ...          ...
# 79 2014-09-04 07:00:00    38.667629     3.790953     0.964825     6.206285
# 80 2014-09-04 08:00:00    39.156419     3.835548     1.036389     6.375585
# 81 2014-09-04 09:00:00    39.632950     3.844560     1.038138     6.569600
# 82 2014-09-04 10:00:00    39.687712     3.849807     1.042647     6.465930
# 83 2014-09-04 11:00:00    39.978757     3.841698     1.042898     6.430051
#
#     mape_MT_005  mape_MT_006  mape_MT_007  mape_MT_008  mape_MT_009  ...  \
# 0     11.023991     6.244305    51.966402     5.011514    14.658034  ...
# 1     11.040743     6.155688    51.757438     5.001451    14.668354  ...
# 2     11.111679     6.117865    51.442258     5.091561    14.633045  ...
# 3     11.151026     6.178188    51.557599     5.040898    14.634852  ...
# 4     11.336411     6.168323    52.280230     5.058461    14.779916  ...
# ..          ...          ...          ...          ...          ...  ...
# 79     9.305120     5.293530    52.530985     4.300421    19.874050  ...
# 80     9.309598     5.312395    52.242511     4.296098    19.883452  ...
# 81     9.175175     5.292588    52.745278     4.372635    19.623948  ...
# 82     9.113501     5.163560    52.122535     4.479599    19.582228  ...
# 83     9.153905     5.232876    52.639843     4.506784    19.848068  ...
#
#     mape_MT_361  mape_MT_362  mape_MT_363  mape_MT_364  mape_MT_365  \
# 0      6.904244     6.681340     7.112374     7.430763    30.236986
# 1      6.903178     6.388825     7.093486     7.345950    30.337574
# 2      6.834852     6.412199     6.964326     7.225537    30.523782
# 3      6.852272     6.496354     6.883801     7.101978    30.711624
# 4      6.780372     6.501928     6.864115     6.959664    31.058740
# ..          ...          ...          ...          ...          ...
# 79     7.828710     5.173309     4.310625     4.350362    17.382987
# 80     7.805466     5.101711     4.226050     4.334227    16.658227
# 81     7.758787     5.034820     4.223368     4.324391    16.457392
# 82     7.735545     4.956230     4.256691     3.857614    15.988581
# 83     7.685304     5.037661     4.205767     3.836283    15.365401
#
#     mape_MT_366  mape_MT_367  mape_MT_368  mape_MT_369  mape_MT_370
# 0     14.237464     6.969070     6.762520     6.279935     7.095542
# 1     14.001739     7.018736     6.654484     6.246934     7.030532
# 2     13.894295     7.125739     6.538520     6.208029     6.938292
# 3     14.077132     7.211038     6.442904     6.160923     6.845971
# 4     14.122682     7.303066     6.369201     6.079381     6.863536
# ..          ...          ...          ...          ...          ...
# 79    14.623089     6.046488     7.193053     4.291299     7.343512
# 80    14.794264     6.057444     7.269065     4.369395     7.243498
# 81    14.842459     6.056624     7.383698     4.425072     7.129757
# 82    14.881184     6.033464     7.434248     4.498585     7.166027
# 83    14.881070     6.016202     7.505843     4.549105     7.138525
#
# [84 rows x 370 columns]

# %%
df_mape_50.iloc[:, 1:].mean().mean()
# Out:
# 7.589166441215918

# %%
df_mape_90: DataFrame = rolling_mape_multitarget(targets_piv, p90_piv, 84)

# %%
df_mape_90.iloc[:, 1:].mean().mean()
# Out:
# 13.761469244165124
