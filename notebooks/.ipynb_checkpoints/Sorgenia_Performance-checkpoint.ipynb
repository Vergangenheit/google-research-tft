# %%
import sys
sys.path.insert(0, '..')

# %%
from data_formatters.base import GenericDataFormatter, InputTypes, DataTypes
from data_formatters.sorgenia_wind import SorgeniaFormatter
from expt_settings.configs import ExperimentConfig
from libs.hyperparam_opt import HyperparamOptManager
from libs.tft_model import TemporalFusionTransformer
import libs.utils as utils
import os
import pandas as pd
from pandas import DataFrame, Series, Timestamp, Index
from tqdm import tqdm

# %%
import numpy as np
import tensorflow as tf
import tensorflow.compat.v1 as tf1
from tensorflow.compat.v1 import Session, ConfigProto
from tensorflow.python.eager.context import PhysicalDevice
from typing import Dict, List, Union, Generator
from numpy import load

# %%
if tf.test.gpu_device_name(): 
    print('Default GPU Device:{}'.format(tf.test.gpu_device_name()))
else:
    print("Please install GPU version of TF")
# Out:
# Default GPU Device:/device:GPU:0

# %%
gpu: List[PhysicalDevice] = tf.config.experimental.list_physical_devices('GPU')
tf.config.experimental.set_memory_growth(gpu[0], True)

# %%
# Tensorflow setup
default_keras_session: Session = tf1.keras.backend.get_session()
tf_config: ConfigProto = utils.get_default_tensorflow_config(tf_device="gpu", gpu_id=0)
# Out:
# Selecting GPU ID=0

# %%
file_path: str = r'C:\Users\Lorenzo\PycharmProjects\TFT\outputs\data\sorgenia_wind\data\sorgenia_wind\data\sorgenia_final.csv'

# %%
# extract data into DataFrame
raw_data: DataFrame = pd.read_csv(file_path)
raw_data['time'] = raw_data['time'].astype('datetime64[s]')

# %%
raw_data.head()
# Out:
#      plant_name_up                time      kwh  dew_point_2m_C  \
# 0  UP_MPNTLCDMRN_1 2016-12-31 23:00:00  225.000       -0.902831
# 1  UP_MPNTLCDMRN_1 2017-01-01 00:00:00   65.625       -0.783022
# 2  UP_MPNTLCDMRN_1 2017-01-01 01:00:00   31.875       -0.565645
# 3  UP_MPNTLCDMRN_1 2017-01-01 02:00:00    0.000       -0.331075
# 4  UP_MPNTLCDMRN_1 2017-01-01 03:00:00    0.000       -0.668040
#
#    temperature_2m_C  msl_pressure_hPa  sfc_pressure_hPa  precipitation_1h_mm  \
# 0          4.980909       1028.935552        983.718765         0.000000e+00
# 1          4.890773       1028.693079        983.524042        -1.734723e-15
# 2          4.807044       1028.156679        983.034144        -1.734723e-15
# 3          4.911959       1028.162779        983.062126        -1.734723e-15
# 4          4.464566       1027.616920        982.551146        -1.734723e-15
#
#    wind_speed_mean_10m_1h_ms  wind_speed_mean_100m_1h_ms  ...  \
# 0                   1.381208                    2.254668  ...
# 1                   1.278206                    2.224647  ...
# 2                   1.211802                    2.130597  ...
# 3                   1.017035                    1.846413  ...
# 4                   0.715094                    1.450024  ...
#
#    days_from_start               id  hour  day  day_of_week  month  \
# 0                0  UP_MPNTLCDMRN_1    23   31            5     12
# 1                0  UP_MPNTLCDMRN_1     0    1            6      1
# 2                0  UP_MPNTLCDMRN_1     1    1            6      1
# 3                0  UP_MPNTLCDMRN_1     2    1            6      1
# 4                0  UP_MPNTLCDMRN_1     3    1            6      1
#
#     categorical_id  hours_from_start  categorical_day_of_week  \
# 0  UP_MPNTLCDMRN_1               0.0                        5
# 1  UP_MPNTLCDMRN_1               1.0                        6
# 2  UP_MPNTLCDMRN_1               2.0                        6
# 3  UP_MPNTLCDMRN_1               3.0                        6
# 4  UP_MPNTLCDMRN_1               4.0                        6
#
#    categorical_hour
# 0                23
# 1                 0
# 2                 1
# 3                 2
# 4                 3
#
# [5 rows x 31 columns]

# %%
config = ExperimentConfig('sorgenia_wind', r'C:\Users\Lorenzo\PycharmProjects\TFT\outputs')

# %% [markdown]
# # START WITH MODEL1

# %% [markdown]
# Wind Forecasts as known input

# %%
formatter: SorgeniaFormatter = config.make_data_formatter()

# %%
data_csv_path: str = config.data_csv_path

# %% [markdown]
# # SPLIT DATA

# %%
train, valid, test = formatter.split_data(raw_data)
# Out:
# Setting scalers with training data...

# %% [markdown]
# # OPEN PREDICTIONS AND TARGETS FILES

# %%
wind_known_path: str = r'C:\Users\Lorenzo\savedmodels_sorgenia_wind_known'

# %%
p50_forecast: DataFrame = pd.read_csv(os.path.join(wind_known_path, "p50.csv"))
p90_forecast: DataFrame = pd.read_csv(os.path.join(wind_known_path, "p90.csv"))
targets: DataFrame = pd.read_csv(os.path.join(wind_known_path, "targets.csv"))
targets['forecast_time'] = targets['forecast_time'].astype('datetime64[s]')
p50_forecast['forecast_time'] = p50_forecast['forecast_time'].astype('datetime64[s]')
p90_forecast['forecast_time'] = p90_forecast['forecast_time'].astype('datetime64[s]')

# %%
p50_forecast.head()
# Out:
#         forecast_time       identifier        t+0         t+1        t+2  \
# 0 2020-08-13 22:00:00  UP_MPNTLCDMRN_1    94.7528   236.21342  325.15270
# 1 2020-08-13 23:00:00  UP_MPNTLCDMRN_1  1657.0032  1147.29830  676.12320
# 2 2020-08-14 00:00:00  UP_MPNTLCDMRN_1  1914.3452  1136.45910  711.58710
# 3 2020-08-14 01:00:00  UP_MPNTLCDMRN_1  1109.7296   834.60860  563.53094
# 4 2020-08-14 02:00:00  UP_MPNTLCDMRN_1  1327.7163   889.43480  561.01917
#
#          t+3        t+4        t+5        t+6         t+7         t+8  \
# 0  307.60492  294.89087  246.62157  163.40056  103.391716   114.31194
# 1  469.01343  347.40050  235.92680  150.77953  158.330250   440.21902
# 2  487.57380  344.98242  206.81010  194.00963  509.816930   810.82104
# 3  363.60790  183.96867  153.01237  492.92365  823.356100   682.92035
# 4  274.82147  215.57652  569.98700  866.99520  742.008240  1652.62950
#
#          t+9       t+10       t+11
# 0   313.3440   732.8784   652.0716
# 1   761.2005   706.5071  1364.0544
# 2   658.3359  1373.9912  1643.2124
# 3  1556.1431  1759.6161  1981.1287
# 4  1800.0970  2014.1538  2023.6296

# %%
targets.head()
# Out:
#         forecast_time       identifier        t+0        t+1        t+2  \
# 0 2020-08-13 22:00:00  UP_MPNTLCDMRN_1  1999.5000  3033.3750  1952.4375
# 1 2020-08-13 23:00:00  UP_MPNTLCDMRN_1  3033.3750  1952.4375  1969.1250
# 2 2020-08-14 00:00:00  UP_MPNTLCDMRN_1  1952.4375  1969.1250  1177.8750
# 3 2020-08-14 01:00:00  UP_MPNTLCDMRN_1  1969.1250  1177.8750  1275.1875
# 4 2020-08-14 02:00:00  UP_MPNTLCDMRN_1  1177.8750  1275.1875   390.0000
#
#          t+3        t+4        t+5        t+6        t+7        t+8  \
# 0  1969.1250  1177.8750  1275.1875   390.0000     3.7500   225.0000
# 1  1177.8750  1275.1875   390.0000     3.7500   225.0000   832.6875
# 2  1275.1875   390.0000     3.7500   225.0000   832.6875  1020.1875
# 3   390.0000     3.7500   225.0000   832.6875  1020.1875   585.0000
# 4     3.7500   225.0000   832.6875  1020.1875   585.0000  1426.1250
#
#          t+9       t+10      t+11
# 0   832.6875  1020.1875   585.000
# 1  1020.1875   585.0000  1426.125
# 2   585.0000  1426.1250  2937.000
# 3  1426.1250  2937.0000  1623.750
# 4  2937.0000  1623.7500  1582.875

# %%
p90_forecast.head()
# Out:
#         forecast_time       identifier         t+0         t+1        t+2  \
# 0 2020-08-13 22:00:00  UP_MPNTLCDMRN_1   431.28275   796.88684  1015.1233
# 1 2020-08-13 23:00:00  UP_MPNTLCDMRN_1  2631.32810  2331.46360  1723.1796
# 2 2020-08-14 00:00:00  UP_MPNTLCDMRN_1  2941.78860  2351.34960  1879.6521
# 3 2020-08-14 01:00:00  UP_MPNTLCDMRN_1  1965.91980  1830.49940  1536.1088
# 4 2020-08-14 02:00:00  UP_MPNTLCDMRN_1  2183.02080  1886.11350  1496.8760
#
#           t+3         t+4         t+5         t+6         t+7         t+8  \
# 0   978.50490   950.59420   844.57117   654.05040   483.77230   522.96497
# 1  1367.84850  1112.24240   905.28810   694.56445   741.45026  1328.59810
# 2  1458.73320  1135.94670   849.97565   851.12120  1506.69270  1968.50650
# 3  1147.47520   756.76324   666.90094  1359.72020  1914.51460  1557.36720
# 4  1014.66675   854.17346  1534.06480  1966.16910  1631.58080  2666.48680
#
#           t+9       t+10       t+11
# 0   978.26685  1687.2004  1543.1346
# 1  1854.85280  1650.9906  2457.6096
# 2  1641.61790  2496.5151  2744.0544
# 3  2576.78030  2778.3845  2901.9946
# 4  2825.91200  2950.6550  2931.4850

# %% [markdown]
# IMPORT FUNCTIONS TO TRANSFORM DF AND CALCULATE MAPE

# %%
from inference import mape
from inference import utils

# %%
# test targets matching with raw_data
utils.test_targets(targets, raw_data, 'time', 12, 2)
# Out:
# 22946it [06:06, 62.66it/s]

# %% [markdown]
# PIVOT TARGETS AND PREDS

# %%
targets_piv: DataFrame = utils.pivot(targets)
p50_piv: DataFrame = utils.pivot(p50_forecast)
p90_piv: DataFrame = utils.pivot(p90_forecast)
# Out:
# ..\inference\utils.py:52: FutureWarning: The default value of regex will change from True to False in a future version.
#   row['forecast_time'] = row['forecast_time'] + pd.Timedelta(hours=row['level_1'])
# ..\inference\utils.py:52: FutureWarning: The default value of regex will change from True to False in a future version.
#   row['forecast_time'] = row['forecast_time'] + pd.Timedelta(hours=row['level_1'])
# ..\inference\utils.py:52: FutureWarning: The default value of regex will change from True to False in a future version.
#   row['forecast_time'] = row['forecast_time'] + pd.Timedelta(hours=row['level_1'])

# %%
targets_piv.head()
# Out:
#         forecast_time  UP_MPNTLCDMRN_1  UP_MPNTLCSMBC_1  UP_PEPIZZA_1  \
# 0 2020-08-13 23:00:00        1999.5000         958.9475        968.25
# 1 2020-08-14 00:00:00        3033.3750        1320.9375        979.50
# 2 2020-08-14 01:00:00        1952.4375        1060.8025        250.50
# 3 2020-08-14 02:00:00        1969.1250         382.5350        910.50
# 4 2020-08-14 03:00:00        1177.8750        1341.3350       1471.50
#
#    UP_PRCLCDMZRD_1  UP_PRCLCDPLRM_1  UP_PRCLCDPRZZ_1  UP_PRCLCMINEO_1
# 0       230.784158         1723.125         3882.825           225.15
# 1       360.259093         3213.675         5392.950          1142.40
# 2        23.228734         1980.900         3550.050          3746.10
# 3       363.637708         1994.325         2307.900          1706.25
# 4      2285.976416         1029.900         1194.525            69.15

# %%
p50_piv.head()
# Out:
#         forecast_time  UP_MPNTLCDMRN_1  UP_MPNTLCSMBC_1  UP_PEPIZZA_1  \
# 0 2020-08-13 23:00:00         94.75280        700.89124     832.75604
# 1 2020-08-14 00:00:00        236.21342        471.63696     870.30610
# 2 2020-08-14 01:00:00       1147.29830        442.05334     855.97797
# 3 2020-08-14 02:00:00        307.60492        395.35608     849.84467
# 4 2020-08-14 03:00:00        294.89087        391.54486     856.45670
#
#    UP_PRCLCDMZRD_1  UP_PRCLCDPLRM_1  UP_PRCLCDPRZZ_1  UP_PRCLCMINEO_1
# 0         498.8829       1183.89360        805.38330        10.358035
# 1         555.8575        851.94190        565.13380        48.322390
# 2         566.2686       1155.96410       1212.17100       843.145100
# 3         607.4703        570.86786        201.98827       438.212400
# 4         971.8403        431.29358        142.96434       257.731700

# %%
p90_piv.head()
# Out:
#         forecast_time  UP_MPNTLCDMRN_1  UP_MPNTLCSMBC_1  UP_PEPIZZA_1  \
# 0 2020-08-13 23:00:00        431.28275       1194.48080     1457.2350
# 1 2020-08-14 00:00:00        796.88684        860.63837     1493.2479
# 2 2020-08-14 01:00:00       2331.46360        766.44020     1438.0261
# 3 2020-08-14 02:00:00        978.50490        676.89343     1419.4735
# 4 2020-08-14 03:00:00        950.59420        684.63495     1489.5775
#
#    UP_PRCLCDMZRD_1  UP_PRCLCDPLRM_1  UP_PRCLCDPRZZ_1  UP_PRCLCMINEO_1
# 0        1067.7070        2000.2390        2013.6917        456.73096
# 1        1153.3906        1852.4360        1941.7083        649.09720
# 2        1197.1760        2283.3620        3251.8892       2228.14480
# 3        1512.3470        1564.5599        1150.8121       1595.90380
# 4        2500.8906        1302.2809         900.7057       1218.65800

# %%
p90_piv.shape, p50_piv.shape, targets_piv.shape
# Out:
# ((3311, 8), (3311, 8), (3311, 8))

# %% [markdown]
# CHECK IF DATE RANGE IS THE SAME

# %%
assert np.array_equal(targets_piv['forecast_time'].values, p50_piv['forecast_time'].values)
assert np.array_equal(targets_piv['forecast_time'].values, p90_piv['forecast_time'].values)
