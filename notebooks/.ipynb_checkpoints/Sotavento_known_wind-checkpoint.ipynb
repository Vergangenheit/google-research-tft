# %%
import sys
sys.path.insert(0, '..')

# %%
import numpy as np
import pandas as pd
from pandas import DataFrame, Series, Timestamp
import tensorflow as tf
import tensorflow.compat.v1 as tf1
from tensorflow.compat.v1 import Session, ConfigProto
from tensorflow.python.eager.context import PhysicalDevice
from typing import Dict, List, Union, Generator
import os
from numpy import load
import time
from data_formatters.base import GenericDataFormatter, InputTypes, DataTypes
import plotly.graph_objects as go
from plotly.graph_objects import Figure

# %%
from inference import mape
from inference import utils as infutils
from inference import evaluate

# %% [markdown]
# # EXPERIMENT 9 - ANEMOMETER DATA + METEOMATICS KNOWN WIND

# %%
# experiment7 = r'C:\Users\Lorenzo\savedmodels_sotavento_anemometer_meteomatics'

# %%
experiment9: str = r'C:\Users\Lorenzo\savedmodels_sotavento_known_wind'

# %%
_column_definition = [
        ('id', DataTypes.REAL_VALUED, InputTypes.ID),
        ('speed_ms', DataTypes.REAL_VALUED, InputTypes.OBSERVED_INPUT),
        ('direction_deg', DataTypes.DATE, InputTypes.OBSERVED_INPUT),
        ('energy_kwh', DataTypes.REAL_VALUED, InputTypes.TARGET),
        ('time', DataTypes.DATE, InputTypes.TIME),
        ('hour', DataTypes.REAL_VALUED, InputTypes.KNOWN_INPUT),
        ('day_of_week', DataTypes.REAL_VALUED, InputTypes.KNOWN_INPUT),
        ('hours_from_start', DataTypes.REAL_VALUED, InputTypes.KNOWN_INPUT),
        ('categorical_id', DataTypes.CATEGORICAL, InputTypes.STATIC_INPUT),
        ('dew_point_2m_c', DataTypes.REAL_VALUED, InputTypes.OBSERVED_INPUT),
        ('t_2m_c', DataTypes.REAL_VALUED, InputTypes.OBSERVED_INPUT),
        ('msl_pressure_hpa', DataTypes.REAL_VALUED, InputTypes.OBSERVED_INPUT),
        ('sfc_pressure_hpa', DataTypes.REAL_VALUED, InputTypes.OBSERVED_INPUT),
        ('precip_1h_mm', DataTypes.REAL_VALUED, InputTypes.OBSERVED_INPUT),
        ('wind_speed_mean_10m_1h_ms', DataTypes.REAL_VALUED, InputTypes.KNOWN_INPUT),
        ('wind_speed_mean_100m_1h_ms', DataTypes.REAL_VALUED, InputTypes.KNOWN_INPUT),
        ('wind_dir_mean_100m_1h_d', DataTypes.REAL_VALUED, InputTypes.KNOWN_INPUT),
        ('wind_dir_mean_10m_1h_d', DataTypes.REAL_VALUED, InputTypes.KNOWN_INPUT),
        ('wind_gusts_10m_1h_ms', DataTypes.REAL_VALUED, InputTypes.KNOWN_INPUT),
        ('wind_gusts_10m_ms', DataTypes.REAL_VALUED, InputTypes.KNOWN_INPUT),
        ('wind_gusts_100m_1h_ms', DataTypes.REAL_VALUED, InputTypes.KNOWN_INPUT),
        ('wind_gusts_100m_ms', DataTypes.REAL_VALUED, InputTypes.KNOWN_INPUT),
        ('Day sin', DataTypes.REAL_VALUED, InputTypes.KNOWN_INPUT),
        ('Day cos', DataTypes.REAL_VALUED, InputTypes.KNOWN_INPUT),
        ('Year sin', DataTypes.REAL_VALUED, InputTypes.KNOWN_INPUT),
        ('Year cos', DataTypes.REAL_VALUED, InputTypes.KNOWN_INPUT),
    ]

# %% [markdown]
# CALCULATE MAPE

# %%
df_mape = evaluate.evaluate(experiment9, 'sotavento_anemometer_meteomatics_known_wind', 700)
# Out:
# sotavento_anemometer_meteomatics_known_wind  77.52606708800748

# %%
fig: Figure = evaluate.boxplotter(df_mape)
fig.show()
# Out:
# <div>                            <div id="afb84672-9917-4e41-b055-2ff91d5048ae" class="plotly-graph-div" style="height:500px; width:1000px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("afb84672-9917-4e41-b055-2ff91d5048ae")) {                    Plotly.newPlot(                        "afb84672-9917-4e41-b055-2ff91d5048ae",                        [{"name": "1h", "type": "box", "y": [83.27439908780123, 83.27625691999873, 83.28298358996499, 83.28667593777787, 83.28728618051977, 83.28031845925518, 83.27420880622377, 83.26807523935537, 83.27370223966255, 83.28502542335822, 83.29055953353986, 83.29626207223897, 83.29074887477788, 83.26696128003366, 83.24817816561406, 83.2353750170808, 83.22840621457436, 83.22886923966959, 83.23105151004837, 83.2405965296611, 83.23264540921757, 83.28788999725072, 83.34001513469568, 83.33451126000617, 83.30349687665696, 83.25607572254856, 83.20565391075885, 83.15697567903146, 83.10910355801134, 83.06209395741746, 83.05775871888304, 83.05832112082385, 83.05